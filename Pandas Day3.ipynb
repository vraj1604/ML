# %%
import pandas as pd

# %%
mdf=pd.read_csv('Movie-Data.csv')
mdf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#To print only column names
clist=mdf.columns
clist
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
mdf.shape
# Out:
# (1000, 12)

# %%
#To know total numbers of null value in particular column 
mdf.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#To print only given column
subset=mdf['Genre']
subset
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
type(subset)
# Out:
# pandas.core.series.Series

# %%
sub=mdf[['Genre','Director']]
sub
# Out:
#                         Genre              Director
# 0     Action,Adventure,Sci-Fi            James Gunn
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott
# 2             Horror,Thriller    M. Night Shyamalan
# 3     Animation,Comedy,Family  Christophe Lourdelet
# 4    Action,Adventure,Fantasy            David Ayer
# ..                        ...                   ...
# 995       Crime,Drama,Mystery             Billy Ray
# 996                    Horror              Eli Roth
# 997       Drama,Music,Romance            Jon M. Chu
# 998          Adventure,Comedy        Scot Armstrong
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
type(sub)
# Out:
# pandas.core.frame.DataFrame

# %%
#To print top 5 column of sub
sub.head()
# Out:
#                       Genre              Director
# 0   Action,Adventure,Sci-Fi            James Gunn
# 1  Adventure,Mystery,Sci-Fi          Ridley Scott
# 2           Horror,Thriller    M. Night Shyamalan
# 3   Animation,Comedy,Family  Christophe Lourdelet
# 4  Action,Adventure,Fantasy            David Ayer

# %%
#To print only rows between 15-20
#iloc for integers
mdf.iloc[15:20]
# Out:
#     Rank                    Title                       Genre  \
# 15    16  The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17            Hacksaw Ridge     Biography,Drama,History
# 17    18             Jason Bourne             Action,Thriller
# 18    19                     Lion             Biography,Drama
# 19    20                  Arrival        Drama,Mystery,Sci-Fi
#
#                                           Description          Director  \
# 15  The quiet life of a terrier named Max is upend...      Chris Renaud
# 16  WWII American Army Medic Desmond T. Doss, who ...        Mel Gibson
# 17  The CIA's most dangerous former operative is d...   Paul Greengrass
# 18  A five-year-old Indian boy gets lost on the st...       Garth Davis
# 19  When twelve mysterious spacecraft appear aroun...  Denis Villeneuve
#
#                                                Actors  Year  \
# 15  Louis C.K., Eric Stonestreet, Kevin Hart, Lake...  2016
# ...

# %%
#To print all detials of individual row
#We have to take only index value to fetch data row wise
mdf.iloc[15]
# Out:
# Rank                                                                 16
# Title                                           The Secret Life of Pets
# Genre                                        Animation,Adventure,Comedy
# Description           The quiet life of a terrier named Max is upend...
# Director                                                   Chris Renaud
# Actors                Louis C.K., Eric Stonestreet, Kevin Hart, Lake...
# Year                                                               2016
# Runtime (Minutes)                                                    87
# Rating                                                              6.6
# Votes                                                            120259
# Revenue (Millions)                                               368.31
# Metascore                                                          61.0
# Name: 15, dtype: object

# %%
#TO take any column at index place
mdf=pd.read_csv('Movie-Data.csv', index_col='Genre')
mdf
# Out:
#                           Rank                    Title  \
# Genre
# Action,Adventure,Sci-Fi      1  Guardians of the Galaxy
# Adventure,Mystery,Sci-Fi     2               Prometheus
# Horror,Thriller              3                    Split
# Animation,Comedy,Family      4                     Sing
# Action,Adventure,Fantasy     5            Suicide Squad
# ...                        ...                      ...
# Crime,Drama,Mystery        996     Secret in Their Eyes
# Horror                     997          Hostel: Part II
# Drama,Music,Romance        998   Step Up 2: The Streets
# Adventure,Comedy           999             Search Party
# Comedy,Family,Fantasy     1000               Nine Lives
#
#                                                                 Description  \
# Genre
# Action,Adventure,Sci-Fi   A group of intergalactic criminals are forced ...
# Adventure,Mystery,Sci-Fi  Following clues to the origin of mankind, a te...
# ...

# %%
#If we make 'Genre' column as index column then loc[Genre's Name] is used to fetch Genres Names row
mdf.loc['Horror']
# Out:
#         Rank                                 Title  \
# Genre
# Horror    43               Don't Fuck in the Woods
# Horror   259                            Lights Out
# Horror   270                               Satanic
# Horror   303                The Cabin in the Woods
# Horror   402                        The Black Room
# Horror   624                       Friday the 13th
# Horror   676                              The Mist
# Horror   859                   The Hills Have Eyes
# Horror   937  The Human Centipede (First Sequence)
# Horror   989                               Martyrs
# Horror   997                       Hostel: Part II
#
#                                               Description           Director  \
# Genre
# Horror  A group of friends are going on a camping trip...      Shawn Burkett
# Horror  Rebecca must unlock the terror behind her litt...  David F. Sandberg
# Horror  Four friends on their way to Coachella stop of...    Jeffrey G. Hunt
# ...

# %%
#To print data between 700 to 800
mdf.iloc[700:800]
# Out:
#                             Rank                        Title  \
# Genre
# Crime,Drama,Horror           701                  Funny Games
# Comedy,Fantasy               702                          Ted
# Action,Comedy,Crime          703                          RED
# Adventure,Drama,Romance      704                    Australia
# Action,Crime,Drama           705                       Faster
# ...                          ...                          ...
# Comedy,Romance               796          No Strings Attached
# Adventure,Biography,Drama    797                  Rescue Dawn
# Animation,Adventure,Comedy   798              Despicable Me 2
# Crime,Drama,Mystery          799  A Walk Among the Tombstones
# Action,Comedy,Sci-Fi         800              The World's End
#
#                                                                   Description  \
# Genre
# Crime,Drama,Horror          Two psychopathic young men take a family hosta...
# ...

# %%
mdf=pd.read_csv('Movie-Data.csv')
mdf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
mdf['Year']==2012
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Year, Length: 1000, dtype: bool

# %%
#Print Data whose year is 2012 without making year AS INDEX
data=mdf[mdf['Year']==2012]
data
# Out:
#      Rank                       Title                      Genre  \
# 1       2                  Prometheus   Adventure,Mystery,Sci-Fi
# 76     77                The Avengers              Action,Sci-Fi
# 124   125       The Dark Knight Rises            Action,Thriller
# 135   136  The Place Beyond the Pines       Crime,Drama,Thriller
# 144   145            Django Unchained              Drama,Western
# ..    ...                         ...                        ...
# 916   917           The Expendables 2  Action,Adventure,Thriller
# 929   930                  The Master                      Drama
# 957   958                End of Watch       Crime,Drama,Thriller
# 972   973                Rock of Ages       Comedy,Drama,Musical
# 994   995                   Project X                     Comedy
#
#                                            Description              Director  \
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
#Print movies directed by Ridley Scott
data2=mdf[mdf['Director']=='Ridley Scott']
data2
# Out:
#      Rank                   Title                     Genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            Description      Director  \
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# ...

# %%
#Print Data whose year is after 2012 without making year AS INDEX
data=mdf[mdf['Year']>=2012]
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 989   990                    Selma   Biography,Drama,History
# 994   995                Project X                    Comedy
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#Print Data whose year is between 2012 to 2018 without making year AS INDEX
data=mdf[(mdf['Year']>=2012) & (mdf['Year']<=2018) ]
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 989   990                    Selma   Biography,Drama,History
# 994   995                Project X                    Comedy
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#Print Movies that were released between 2005-2010 , have rating above 8 but made below revenue percentage of 25 
data3=mdf[(mdf['Year']>=2005) & (mdf['Year']<=2010) & (mdf['Rating']>=8.0) & (mdf['Revenue (Millions)']<=25)]
data3
# Out:
#      Rank                   Title                      Genre  \
# 197   198           Into the Wild  Adventure,Biography,Drama
# 430   431                3 Idiots               Comedy,Drama
# 476   477     The Lives of Others             Drama,Thriller
# 713   714               Incendies          Drama,Mystery,War
# 742   743  El secreto de sus ojos      Drama,Mystery,Romance
# 991   992        Taare Zameen Par         Drama,Family,Music
#
#                                            Description  \
# 197  After graduating from Emory University, top st...
# 430  Two friends are searching for their long lost ...
# 476  In 1984 East Berlin, an agent of the secret po...
# 713  Twins journey to the Middle East to discover t...
# 742  A retired legal counselor writes a novel hopin...
# 991  An eight-year-old boy is thought to be a lazy ...
#
#                              Director  \
# 197                         Sean Penn
# 430                   Rajkumar Hirani
# ...
