# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('census_data.csv')

# %%
data
print('Shape',data.shape)
print('Size:',data.size)
# Out:
# Shape (32561, 14)
# Size: 455854

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'race', 'gender', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'income_bracket'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education_num   32561 non-null  int64
#  4   marital_status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   gender          32561 non-null  object
#  9   capital_gain    32561 non-null  int64
#  10  capital_loss    32561 non-null  int64
#  11  hours_per_week  32561 non-null  int64
#  12  native_country  32561 non-null  object
#  13  income_bracket  32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# gender            0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income_bracket    0
# dtype: int64

# %%
data.head(5)
# Out:
#    age          workclass   education  education_num       marital_status  \
# 0   39          State-gov   Bachelors             13        Never-married
# 1   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 2   38            Private     HS-grad              9             Divorced
# 3   53            Private        11th              7   Married-civ-spouse
# 4   28            Private   Bachelors             13   Married-civ-spouse
#
#            occupation    relationship    race   gender  capital_gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital_loss  hours_per_week  native_country income_bracket
# ...

# %%
data.tail(5)
# Out:
#        age      workclass    education  education_num       marital_status  \
# 32556   27        Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40        Private      HS-grad              9   Married-civ-spouse
# 32558   58        Private      HS-grad              9              Widowed
# 32559   22        Private      HS-grad              9        Never-married
# 32560   52   Self-emp-inc      HS-grad              9   Married-civ-spouse
#
#                occupation relationship    race   gender  capital_gain  \
# 32556        Tech-support         Wife   White   Female             0
# 32557   Machine-op-inspct      Husband   White     Male             0
# 32558        Adm-clerical    Unmarried   White   Female             0
# 32559        Adm-clerical    Own-child   White     Male             0
# 32560     Exec-managerial         Wife   White   Female         15024
#
#        capital_loss  hours_per_week  native_country income_bracket
# ...

# %%
data.duplicated().value_counts()
# Out:
# False    29096
# True      3465
# dtype: int64

# %%
plt.plot(data['age'],data['hours_per_week'])

# %%
data.plot(kind='scatter',x='relationship',y='marital_status')
plt.grid()
plt.title('Relationship Vs Marital Status')
# Out:
# Text(0.5, 1.0, 'Relationship Vs Marital Status')

# %%
sns.set(style='darkgrid')
sns.scatterplot(x='age',y='education',hue='income_bracket',data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='education'>

# %%
sns.relplot(x='capital_gain',y='capital_loss',hue='marital_status',data=data)

# %%
sns.catplot(x='age',y='marital_status',kind='bar',hue='gender',data=data)

# %%
sns.catplot(y='marital_status',kind='count',hue='gender',data=data)

# %%
sns.catplot(x='age',kind='count',hue='gender',data=data)

# %%
ra=data['race']
ra
# Out:
# 0         White
# 1         White
# 2         White
# 3         Black
# 4         Black
#           ...
# 32556     White
# 32557     White
# 32558     White
# 32559     White
# 32560     White
# Name: race, Length: 32561, dtype: object

# %%
ra.unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
whiterace=data[data['race']=='Amer-Indian-Eskimo']
len(whiterace)
# Out:
# 0

# %%
hours = data[data['hours_per_week']==38]
hours
# Out:
#        age   workclass      education  education_num       marital_status  \
# 38      31     Private   Some-college             10   Married-civ-spouse
# 46      53     Private        HS-grad              9   Married-civ-spouse
# 150     47   Local-gov   Some-college             10             Divorced
# 180     44   Local-gov   Some-college             10   Married-civ-spouse
# 231     41     Private        HS-grad              9             Divorced
# ...    ...         ...            ...            ...                  ...
# 32239   36     Private        HS-grad              9            Separated
# 32328   31     Private           10th              6             Divorced
# 32446   53     Private        HS-grad              9              Widowed
# 32508   45     Private           10th              6             Divorced
# 32556   27     Private     Assoc-acdm             12   Married-civ-spouse
#
#                occupation    relationship    race   gender  capital_gain  \
# ...
